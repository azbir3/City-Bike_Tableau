# %%
from zipfile import ZipFile
from urllib.request import urlopen   
import pandas as pd
import os

URLs = ['https://s3.amazonaws.com/tripdata/201901-citibike-tripdata.csv.zip',\
        
        'https://s3.amazonaws.com/tripdata/201903-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201904-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201905-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201906-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201907-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201908-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201909-citibike-tripdata.csv.zip',\
        'https://s3.amazonaws.com/tripdata/201910-citibike-tripdata.csv.zip']
       
       
dfs=[]
for URL in URLs:
# open and save the zip file onto computer
    url = urlopen(URL)
    output = open('data/2019zipFile.zip', 'wb')    # note the flag:  "wb"        
    output.write(url.read())
    output.close()

# read the zip file as a pandas dataframe
    df = pd.read_csv('data/2019zipFile.zip')      
    dfs.append(df)

# remove zipfile 
os.remove('data/2019zipFile.zip')

# %%
df = pd.concat(dfs)
df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# 5                 535  2019-01-01 00:08:33.1790  2019-01-01 00:17:28.3540
# 6                 280  2019-01-01 00:09:21.0060  2019-01-01 00:14:01.1510
# 7                1547  2019-01-01 00:11:22.9070  2019-01-01 00:37:10.0550
# 8                 300  2019-01-01 00:12:17.9310  2019-01-01 00:17:18.8300
# 9                 123  2019-01-01 00:12:19.6030  2019-01-01 00:14:23.1040
# 10                932  2019-01-01 00:14:02.7970  2019-01-01 00:29:35.0450
# 11                209  2019-01-01 00:15:09.9730  2019-01-01 00:18:39.0110
# ...

# %%
df.count()
# Out:
# tripduration               17174035
# starttime                  17174035
# stoptime                   17174035
# start station id           17173864
# start station name         17173864
# start station latitude     17174035
# start station longitude    17174035
# end station id             17173864
# end station name           17173864
# end station latitude       17174035
# end station longitude      17174035
# bikeid                     17174035
# usertype                   17174035
# birth year                 17174035
# gender                     17174035
# dtype: int64

# %%
# Drop all rows with missing information
df_clean = df.dropna(how='any')

df_clean.count()
# Out:
# tripduration               17173864
# starttime                  17173864
# stoptime                   17173864
# start station id           17173864
# start station name         17173864
# start station latitude     17173864
# start station longitude    17173864
# end station id             17173864
# end station name           17173864
# end station latitude       17173864
# end station longitude      17173864
# bikeid                     17173864
# usertype                   17173864
# birth year                 17173864
# gender                     17173864
# dtype: int64

# %%
df_clean.head(3)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1           316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2           591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
#
#    start station id           start station name  start station latitude  \
# 0            3160.0  Central Park West & W 76 St               40.778968
# 1             519.0        Pershing Square North               40.751873
# 2            3171.0      Amsterdam Ave & W 82 St               40.785247
#
#    start station longitude  end station id        end station name  \
# 0               -73.973747          3283.0  W 89 St & Columbus Ave
# 1               -73.977706           518.0         E 39 St & 2 Ave
# 2               -73.976673          3154.0         E 77 St & 3 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
link = 'https://s3.amazonaws.com/tripdata/201902-citibike-tripdata.csv.zip'

import urllib.request
urllib.request.urlretrieve(link, 'data/2019FebzipFile.zip')
import zipfile
compressed_file = zipfile.ZipFile('data/2019FebzipFile.zip')
csv_file = compressed_file.open('201902-citibike-tripdata.csv')
dfFeb = pd.read_csv(csv_file)
dfFeb.head(3)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
#
#    start station longitude  end station id        end station name  \
# 0               -73.942300          3501.0  E 118 St & Madison Ave
# 1               -73.985649           236.0     St Marks Pl & 2 Ave
# 2               -73.952918          3549.0   Grand Ave & Bergen St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.801487             -73.944251   33450  Subscriber
# ...

# %%
dfFeb.count()
# Out:
# tripduration               943744
# starttime                  943744
# stoptime                   943744
# start station id           943735
# start station name         943735
# start station latitude     943744
# start station longitude    943744
# end station id             943735
# end station name           943735
# end station latitude       943744
# end station longitude      943744
# bikeid                     943744
# usertype                   943744
# birth year                 943744
# gender                     943744
# dtype: int64

# %%
# Drop all rows with missing information
dfFeb_clean = dfFeb.dropna(how='any')

# %%
dfFeb_clean.count()
# Out:
# tripduration               943735
# starttime                  943735
# stoptime                   943735
# start station id           943735
# start station name         943735
# start station latitude     943735
# start station longitude    943735
# end station id             943735
# end station name           943735
# end station latitude       943735
# end station longitude      943735
# bikeid                     943735
# usertype                   943735
# birth year                 943735
# gender                     943735
# dtype: int64

# %%
frames = [df_clean, dfFeb_clean]
result = pd.concat(frames)
result
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# 5                535  2019-01-01 00:08:33.1790  2019-01-01 00:17:28.3540
# 6                280  2019-01-01 00:09:21.0060  2019-01-01 00:14:01.1510
# 7               1547  2019-01-01 00:11:22.9070  2019-01-01 00:37:10.0550
# 8                300  2019-01-01 00:12:17.9310  2019-01-01 00:17:18.8300
# 9                123  2019-01-01 00:12:19.6030  2019-01-01 00:14:23.1040
# 10               932  2019-01-01 00:14:02.7970  2019-01-01 00:29:35.0450
# 11               209  2019-01-01 00:15:09.9730  2019-01-01 00:18:39.0110
# ...

# %%
result = pd.concat(frames)

# %%
cleanGender = result[result.gender != 0]

# %%
df2019 = cleanGender[cleanGender['birth year'] > 1935]
df2019
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# 5                535  2019-01-01 00:08:33.1790  2019-01-01 00:17:28.3540
# 6                280  2019-01-01 00:09:21.0060  2019-01-01 00:14:01.1510
# 7               1547  2019-01-01 00:11:22.9070  2019-01-01 00:37:10.0550
# 8                300  2019-01-01 00:12:17.9310  2019-01-01 00:17:18.8300
# 9                123  2019-01-01 00:12:19.6030  2019-01-01 00:14:23.1040
# 10               932  2019-01-01 00:14:02.7970  2019-01-01 00:29:35.0450
# 11               209  2019-01-01 00:15:09.9730  2019-01-01 00:18:39.0110
# ...

# %%
# print df to csv
#df2019.to_csv(os.path.join('data/2019_clean.csv'))
print('saved')
# Out:
# saved

# %%
# remove zip file
#os.remove('data/2019FebzipFile.zip')

# %%
startKipsBay = df2019[(df2019['start station id']==507.0)]
startKipsBay
# Out:
#         tripduration                 starttime                  stoptime  \
# 14               467  2019-01-01 00:16:22.9480  2019-01-01 00:24:10.5430
# 285              538  2019-01-01 01:38:42.7910  2019-01-01 01:47:41.3900
# 317               85  2019-01-01 01:44:36.3240  2019-01-01 01:46:01.9000
# 576              607  2019-01-01 02:34:26.9750  2019-01-01 02:44:34.2880
# 1248             208  2019-01-01 07:12:11.2270  2019-01-01 07:15:39.5540
# 1393             231  2019-01-01 07:56:46.3350  2019-01-01 08:00:38.1080
# 1591            1481  2019-01-01 08:32:04.4550  2019-01-01 08:56:45.6010
# 1708            1571  2019-01-01 08:48:04.0000  2019-01-01 09:14:15.8460
# 1998             150  2019-01-01 09:24:51.1490  2019-01-01 09:27:21.4320
# 2361             129  2019-01-01 10:01:09.4320  2019-01-01 10:03:19.3260
# 2385             270  2019-01-01 10:03:17.3730  2019-01-01 10:07:48.3530
# 2577             281  2019-01-01 10:17:41.3900  2019-01-01 10:22:22.7870
# ...

# %%
# print df to csv
startKipsBay.to_csv(os.path.join('data/2019_KipsBay.csv'))
print('saved')
# Out:
# saved

# %%
# The path to our CSV file
file18 = "data/2018_KipsBay.csv"

# Read the data into pandas
df18 = pd.read_csv(file18, index_col=0)
df18
# Out:
#          tripduration                 starttime                  stoptime  \
# 380071            149  2018-01-01 00:16:03.4740  2018-01-01 00:18:33.3040
# 380072            273  2018-01-01 08:52:57.6220  2018-01-01 08:57:31.4970
# 380073           1323  2018-01-01 10:04:27.9660  2018-01-01 10:26:31.7220
# 380074            866  2018-01-01 11:26:02.3530  2018-01-01 11:40:28.8040
# 380075            661  2018-01-01 11:44:25.3490  2018-01-01 11:55:26.7260
# 380076            345  2018-01-01 12:01:17.0600  2018-01-01 12:07:02.4670
